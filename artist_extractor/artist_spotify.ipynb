# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
import xgboost

# %matplotlib inline

# %%
audio = pd.read_csv('Taylor Swift_all_songs.csv')
audio.drop(['Unnamed: 0', 'album_uri','analysis_url','available_markets','disc_number','duration_ms_y','href','is_local','preview_url','uri','track_number','time_signature','track_number','id'],axis = 1,inplace = True)
audio.head()
# Out:
#    acousticness        artist  danceability  duration_ms_x  energy explicit  \
# 0       0.05270  Taylor Swift         0.613         208186   0.764    False
# 1       0.00845  Taylor Swift         0.649         244826   0.589    False
# 2       0.06790  Taylor Swift         0.696         238253   0.602    False
# 3       0.10600  Taylor Swift         0.615         236413   0.534    False
# 4       0.21600  Taylor Swift         0.750         232253   0.404    False
#
#    instrumentalness  key  liveness  loudness  mode                 name  \
# 0          0.000000    2    0.1970    -6.509     1     ...Ready For It?
# 1          0.000000    2    0.1080    -6.237     1             End Game
# 2          0.000021    0    0.0696    -6.156     0  I Did Something Bad
# 3          0.000018    9    0.0607    -6.719     0       Don?t Blame Me
# 4          0.000357    9    0.0911   -10.178     0             Delicate
#
#    popularity release_date  speechiness    tempo  valence
# ...
